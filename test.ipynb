# %%
"""
import requests
from bs4 import BeautifulSoup

request = requests.get('https://vnexpress.net/tin-tuc-24h')

html_doc = request.text
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.find(id='down-app-popup_vne')) # result: None
print(soup.find(id='sis_slider')) # resutl: có kết quả"""

# %%
import requests
from bs4 import BeautifulSoup

# %%
request = requests.get('https://vnexpress.net/tin-tuc-24h')

# %%
request.content
# Out:
# b'<!DOCTYPE html>\n<html lang="vi" xmlns="http://www.w3.org/1999/xhtml">\n<head>\n<title>Tin t\xe1\xbb\xa9c 24h t\xe1\xba\xa1i Vi\xe1\xbb\x87t Nam &amp; Th\xe1\xba\xbf gi\xe1\xbb\x9bi m\xe1\xbb\x9bi nh\xe1\xba\xa5t [H\xc3\x94M NAY]</title> <meta name="description" content="C\xe1\xba\xadp nh\xe1\xba\xadt tin t\xe1\xbb\xa9c 24/7: Th\xe1\xbb\x9di s\xe1\xbb\xb1, Gi\xe1\xba\xa3i tr\xc3\xad, Th\xe1\xbb\x83 thao...t\xe1\xba\xa1i Vi\xe1\xbb\x87t Nam &amp; Th\xe1\xba\xbf gi\xe1\xbb\x9bi h\xc3\xa0ng ng\xc3\xa0y. Th\xc3\xb4ng tin, h\xc3\xacnh \xe1\xba\xa3nh, video clip HOT c\xe1\xba\xadp nh\xe1\xba\xadt nhanh &amp; tin c\xe1\xba\xady nh\xe1\xba\xa5t."/>\n<meta name="keywords" content="tin t\xe1\xbb\xa9c 24h,tin m\xe1\xbb\x9bi nh\xe1\xba\xa5t,tin t\xe1\xbb\xa9c m\xe1\xbb\x9bi nh\xe1\xba\xa5t,tin t\xe1\xbb\xa9c 24h m\xe1\xbb\x9bi nh\xe1\xba\xa5t,tin t\xe1\xbb\xa9c m\xe1\xbb\x9bi,tin t\xe1\xbb\xa9c online"/>\n<meta name="news_keywords" content="tin t\xe1\xbb\xa9c 24h,tin m\xe1\xbb\x9bi nh\xe1\xba\xa5t,tin t\xe1\xbb\xa9c m\xe1\xbb\x9bi nh\xe1\xba\xa5t,tin t\xe1\xbb\xa9c 24h m\xe1\xbb\x9bi nh\xe1\xba\xa5t,tin t\xe1\xbb\xa9c m\xe1\xbb\x9bi,tin t\xe1\xbb\xa9c online"/>\n<meta charset="utf-8">\n<meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=1" name="viewport"/>\n<meta http-equiv="X-UA-Compatible" content="IE=100"/>\n<meta property="fb:app_id" content="1547540628876392"/>\n<meta http-equiv="REFRESH" content="1800"/>\n<meta name="apple-mobile-web-app-capable" content="yes"/>\n<meta name="apple-mobile-web-app-title" content="Vnexpress.net"/>\n<meta name="tt_article_id" content="1004492"/>\n<meta name="tt_category_id" content="1004492"/>\n<meta name="tt_site_id" content="1000000"/>\n<meta name="tt_site_id_new" content="1004492"/>\n<meta name="tt_list_folder" content="1000000,1004492"/>\n<meta name="tt_list_folder_name" content="VnExpress,M\xe1\xbb\x9bi nh\xe1\xba\xa5t"/>\n<meta name="tt_page_type" content="folder"/>\n<meta name="tt_page_type_new" content="2"/>\n<!-- add meta for pvtt3334 -->\n<!-- end meta for pvtt -->\n<!-- META FOR FACEBOOK -->\n<meta property="og:site_name" content="vnexpress.net"/>\n<meta property="og:rich_attachment" content="true"/>\n<meta property="og:type" content="website"/>\n<meta property="og:url" itemprop="url" content="https://vnexpress.net/tin-tuc-24h"/>\n<meta property="og:image" itemprop="thumbnailUrl" content="https://s1cdn.vnecdn.net/vnexpress/restruct/i/v757/logo_default.jpg"/>\n<meta property="og:image:width" content="800"/>\n<meta property="og:image:height" content="354"/>\n<meta content="Tin t\xe1\xbb\xa9c 24h t\xe1\xba\xa1i Vi\xe1\xbb\x87t Nam &amp; Th\xe1\xba\xbf gi\xe1\xbb\x9bi m\xe1\xbb\x9bi nh\xe1\xba\xa5t [H\xc3\x94M NAY]" itemprop="headline" property="og:title"/>\n<meta content="C\xe1\xba\xadp nh\xe1\xba\xadt tin t\xe1\xbb\xa9c 24/7: Th\xe1\xbb\x9di s\xe1\xbb\xb1, Gi\xe1\xba\xa3i tr\xc3\xad, Th\xe1\xbb\x83 thao...t\xe1\xba\xa1i Vi\xe1\xbb\x87t Nam &amp; Th\xe1\xba\xbf gi\xe1\xbb\x9bi h\xc3\xa0ng ng\xc3\xa0y. Th\xc3\xb4ng tin, h\xc3\xacnh \xe1\xba\xa3nh, video clip HOT c\xe1\xba\xadp nh\xe1\xba\xadt nhanh &amp; tin c\xe1\xba\xady nh\xe1\xba\xa5t." itemprop="description" property="og:description"/>\n<!-- END META FOR FACEBOOK -->\n<meta content="news" itemprop="genre" name="medium"/>\n<meta content="vi-VN" itemprop="inLanguage"/>\n<meta content="" itemprop="articleSection"/>\n<meta content="Tin nhanh VnExpress" itemprop="sourceOrganization" name="source"/>\n<meta name="copyright" content="VnExpress"/>\n<meta name="author" content="VnExpress"/>\n<meta name="robots" content="index,follow"/>\n<meta name="geo.placename" content="Ha Noi, Viet Nam"/>\n<meta name="geo.region" content="VN-HN"/>\n<meta name="geo.position" content="21.030624;105.782431"/>\n<meta name="ICBM" content="21.030624, 105.782431"/>\n<meta name="revisit-after" content="days"/>\n<!-- Twitter Card -->\n<meta name="twitter:card" value="summary"/>\n<meta name="twitter:url" content="https://vne ...
